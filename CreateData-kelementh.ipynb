# %% [markdown]
# <a href="https://colab.research.google.com/github/lephuocdat2000/-CS114.K21-/blob/master/CreateData-kelementh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
sys.setrecursionlimit(1000000)

# %%
import numpy as np
from numpy.random import randint
import pandas as pd
import cProfile
def partition(arr, l, r):
    x = arr[r]
    i = l
    for j in range(l, r):
        if arr[j] <= x:
            arr[i], arr[j] = arr[j], arr[i]
            i += 1
    arr[i], arr[r] = arr[r], arr[i]
    return i

# finds the kth position (of the sorted array)
# in a given unsorted array i.e this function
# can be used to find both kth largest and
# kth smallest element in the array.
# ASSUMPTION: all elements in arr[] are distinct
def kthSmallest(arr, l, r, k):
    # if k is smaller than number of
    # elements in array
    if (k > 0 and k <= r - l + 1):
        # Partition the array around last
        # element and get position of pivot
        # element in sorted array
        index = partition(arr, l, r)
        # if position is same as k
        if (index - l == k - 1):
            return arr[index]
            # If position is more, recur
        # for left subarray
        if (index - l > k - 1):
            return kthSmallest(arr, l, index - 1, k)
            # Else recur for right subarray
        return kthSmallest(arr, index + 1, r,
                           k - index + l - 1)
    return INT_MAX

# %% [markdown]
# #thử với k=constant

# %%
k=30
n=[1000,2000,5000,10000,20000,40000,80000,120000,160000,200000,320000,400000,640000,800000,1000000,1280000,1500000,1700000,2000000,2300000,2560000,5120000,7000000,10240000,13000000,15000000,18000000,20480000,40960000]
for i in n:
  arr=np.zeros(i)
  print(i,k)
  arr=randint(0,1000000000,i)
  cProfile.run('kthSmallest(arr,0,i-1,k)')
# Out:
# 1000 30
#          21 function calls (13 primitive calls) in 0.000 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       9/1    0.000    0.000    0.000    0.000 <ipython-input-44-f1f9abf361ae>:23(kthSmallest)
#         9    0.000    0.000    0.000    0.000 <ipython-input-44-f1f9abf361ae>:8(partition)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# 2000 30
#          23 function calls (14 primitive calls) in 0.002 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      10/1    0.000    0.000    0.002    0.002 <ipython-input-44-f1f9abf361ae>:23(kthSmallest)
#        10    0.002    0.000    0.002    0.000 <ipython-input-44-f1f9abf361ae>:8(partition)
# ...

# %%
k=30
arr=np.zeros(n)
print(n,k)
arr=Random_array(arr,n,1000000000)
cProfile.run('for i in range(5): kthSmallest(arr,0,n-1,k)')

# %% [markdown]
# #thử với n=constant

# %%
n=10000
arr=np.zeros(n)
Random_array(arr,n,1000000000)

# %%
k=1
while(k<10000):
  print(k)
  runtime=cProfile.run('kthSmallest(arr,0,n-1,k)')
  k+=300
# Out:
# 1
#          16369 function calls (8187 primitive calls) in 30.093 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      8183   30.071    0.004   30.071    0.004 <ipython-input-66-f30e93769383>:11(partition)
#    8183/1    0.022    0.000   30.093   30.093 <ipython-input-66-f30e93769383>:26(kthSmallest)
#         1    0.000    0.000   30.093   30.093 <string>:1(<module>)
#         1    0.000    0.000   30.093   30.093 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# 301
#          16879 function calls (8442 primitive calls) in 29.022 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      8438   29.002    0.003   29.002    0.003 <ipython-input-66-f30e93769383>:11(partition)
# ...

# %%
  runtime=cProfile.run('kthSmallest(arr,0,n-1,10000)')
# Out:
#          5 function calls in 0.007 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.007    0.007    0.007    0.007 <ipython-input-66-f30e93769383>:11(partition)
#         1    0.000    0.000    0.007    0.007 <ipython-input-66-f30e93769383>:26(kthSmallest)
#         1    0.000    0.000    0.007    0.007 <string>:1(<module>)
#         1    0.000    0.000    0.007    0.007 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
